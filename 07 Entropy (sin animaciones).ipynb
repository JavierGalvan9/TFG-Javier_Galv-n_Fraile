# %% [markdown]
# ## Density operator
#
# An operator defined as it follows:
#
# \begin{equation}
# \label{eq:density}
# \rho = \sum_j p_j |\psi_j\rangle \langle\psi_j|
# \end{equation}
#
# is the density operator associated to some ensemble $p_j, |\psi_j\rangle$ if and only if it satisfies the conditions:
#
# * Trace condtion: tr(\rho) = 1
# * Positivity: \rho is a positive operator
#
# This conditions require that the coefficients $p_j$ are non-negative and add up to one. In this case, the density operator \eqref{eq:density} represents a mixed state with propability $p_j$ that the system is in the pure state $|\psi_j\rangle$.

# %% [markdown]
# ## Entanglement
#
# Entangled states are very interesting states because they exhibit correlations that have no classical analog. They are of particular importance in quantum computation and quantum information. As an example let us take the entangled bi-partite pure state:
#
# \begin{equation}
# |\psi^+\rangle = \frac{1}{\sqrt{2}} (|01\rangle_{AB} + |10\rangle_{AB}) \in H_A \otimes H_B
# \end{equation}
#
# This state can not be decomposed as a simple product state $|q\rangle_A |p\rangle_B$ for $q, p \in \{0, 1\}$. The state is maximally entangled, i.e. when we trace over the state $B$ then the reduced density operator $\rho_A$ of the system will be a multiple of the identity operator. This means that if we measure in system $A$ in any basis the result will be completely  random (0 or 1 with equal probability 1/2). However, there is a perfect correlation: Whenever we measure 1 in system A then we will measure 0 in system $B$ with certainty and vice versa.

# %% [markdown]
# So lets consider a system constituted of $N$ qubits. The general wave function of the system will be:
#
# \begin{equation}
# |\psi\rangle = \sum_{s_1, ..., s_N \in \{0, 1\}} \langle s_1, ..., s_N|\psi \rangle ~| s_1, ..., s_N\rangle
# \label{eq:global}
# \end{equation}
#
# where the closure relation of the computational basis have been used. In the general case a total amount of $2^N$ coeficients are necessary to fully describe the state of the system. Suppose now the case where the general wave function can be written as the product of the states of two subsystems:
#
# \begin{equation}
# |\psi\rangle = |\phi_1 \rangle \otimes |\phi_2 \rangle
# \end{equation}
#
# where $|\phi_1 \rangle$ is the state of the first $M$ qubits $\{q_1,..., q_M\}$ and $|\phi_2 \rangle$ the state of the $N- M$ following qubits $\{q_{M+1},..., q_N\}$. In this case the total amount of coeficients necessary to characterize all the system is:
#
# \begin{equation}
# \# = 2^{M} + 2^{N-M}
# \end{equation}
#
# which is exponentially less than in the general case above.

# %% [markdown]
# Las transformaciones locales no aumentan el entrelazamiento (ni la entropía por lo tanto), al contrario que las globales que sí lo hacen. Pero presentan una cota superior, es decir, aumentando el número de operaciones globales (CNOTs, etc.) podemos aumentar el entrelazamiento del sistema.

# %% [markdown]
# ## Schmidt decomposition
#
# The Schmidt decomposition is one of the most important tools for analyzing bipartite pure states in quantum information theory and quantifying the level of entanglement of the system. The Schmidt decomposition shows that it is possible to decompose any pure bipartite state as a superposition of corresponding states. We state this result formally as the following theorem:
#
# \begin{theorem}[Schmidt decomposition.]
# Suppose $|\psi\rangle_{AB}$ is a pure state of a composite system, AB.
#
# \begin{equation}
# |\psi\rangle_{AB} \in \mathscr{H}_A \otimes \mathscr{H}_B
# \end{equation}
#
# Then there exist orthonormal states $|i\rangle_A$ for system A, and orthonormal states $|i\rangle_B$ of system B such that the pure state can be expressed as:
#
# \begin{equation}
# \label{eq:schmidt}
# |\psi\rangle_{AB} = \sum_{i=1}^{d} \lambda_i |i\rangle_A |i\rangle_B
# \end{equation}
#
# where the amplitudes $\lambda_i$ are real, strictly positive and normalized so that $\sum_i \lambda_i^2 = 1$. They are known as **Schmidt coefficients**. The **Schmidt rank**, $d$, of a bipartite state, also known as **Schmidt number**, is equal to the number of non-zero Schmidt coefficients $\lambda_i$ in the state Schmidt decomposition.
# \end{theorem}
#
# **Proof.**
# *Consider a composite systems A and B with dimensions $n$ and $m$, respectively, where $n \geq m$. Let $\{|j\rangle_A\}$ and $\{|k\rangle_B\}$ be any fixed orthonormal basis for systems A and B. Then the global state $|\psi_{AB}\rangle$ can be written as:*
#
# \begin{equation}
# \label{eq:proofstate}
# |\psi\rangle_{AB} = \sum_{j=1}^{n} \sum_{k=1}^{m} \alpha_{jk} |j\rangle_A |k\rangle_B
# \end{equation}
#
# *Lets consider now the matrix formed by the complex coefficients $\alpha_{jk}$ which is an $n \times m$ matrix:*
#
# \begin{equation}
# [A_{jk}] = \alpha_{jk}
# \end{equation}
#
# *Since every matrix has a singular value decomposition (SVD) for $A$ we can write:*
#
# \begin{equation}
# \label{eq:proof1}
# A = U \Lambda V^{\dagger}
# \end{equation}
#
# *where $U$ is a $n \times n$ unitary matrix, $V$ is a $m \times m$ unitary matrix and $\Sigma$ is a $n \times m$ matrix with $d$ real, strictly positive coefficients $\lambda_i$ along the diagonal and zeros elsewhere. If we denote the matrix elements of $U$ as $u_{ji}$ and those of $V$ as $v_{ik}$ the above matrix equation \eqref{eq:proof1} is equivalent to the following set of equations:*
#
# \begin{equation}
# \label{eq:proof3}
# \alpha_{jk} = \sum_{i=1}^{d} u_{ji} \lambda_i v_{ik}
# \end{equation}
#
# *Making this substitution into the expression for the state \eqref{eq:proofstate} we get:*
#
# \begin{equation}
# |\psi\rangle_{AB} = \sum_{j=1}^{n} \sum_{k=1}^{m} \left(\sum_{i=1}^{d} u_{ji} \lambda_i v_{ik}\right) |j\rangle_A |k\rangle_B
# \end{equation}
#
# *Readjusting the terms we find that:*
#
# \begin{equation}
# |\psi\rangle_{AB} = \sum_{i=1}^{d} \lambda_i \left(\sum_{j=1}^{n} u_{ji} |j\rangle_A \right) \otimes \left(\sum_{k=1}^{m} v_{ik}  |k\rangle_B \right) =\\
# = \sum_{i=1}^{d} \lambda_i |i\rangle_A |i\rangle_B
# \end{equation}
#
# *where we define the orthonormal basis on system A as $|i\rangle_A \equiv \sum_{j=1}^{n} u_{ji} |j\rangle_A$ and the orthonormal basis on system B as $|i\rangle_B \equiv \sum_{k=1}^{m} v_{ik}  |k\rangle_B$.* Q.E.D.
#
# It is easy to see that setting the normalization condition over the state $|\psi\rangle_{AB}$ requires that the Schmidt coefficients satisfy the relation:
#
# \begin{equation}
# \sum_{i=1}^{d} \lambda_i^2 = 1
# \end{equation}
#
# \begin{remark}
# The Schmidt rank, $d$, satifies the following inequality:
#
# \begin{equation}
# d \leq min \{ dim(\mathscr{H}_A), dim(\mathscr{H}_B) \}
# \end{equation}
#
# This quantity, the total number of non-zero values $\lambda_i$, is known as **Schmidt number** and represents a crucial magnitude in the study of the entanglement of the system. It can be proved that Schmidt number is preserved under unitary transformations on system A or system B alone.
#
# It is easy to prove that a state $|\psi\rangle$ of a composite system AB is a product state if and only if it has Schmidt number 1.
# \end{remark}

# %% [markdown]
# \begin{remark}
# The sets $\{|i\rangle_A\}$ and $\{|i\rangle_B\}$ are orthonormal basis of systems A and B, respectively.
# \end{remark}
#
# **Proof.**
# *Starting with system A we remember that $dim(\mathscr{H}_A) = n$ and that we have defined $|i\rangle_A$ as:*
#
# \begin{equation}
# |i\rangle_A \equiv \sum_{j=1}^{n} u_{ji} |j\rangle_A
# \end{equation}
#
# *where $|j\rangle_A$ constitutes a basis of system A. Since $i$ varies from $1$ to $d$ we see that $dim(\{|i\rangle\}) = d$, where notation related to the system has been omitted. Lets see that this set satisfies the orthonormal relation:*
#
# \begin{equation}
# \langle l|i\rangle = \left( \sum_{k=1}^{n} u_{lk}^{*} \langle k|\right) \left(\sum_{j=1}^{n} u_{ji} |j\rangle \right) =\\
# = \sum_{k=1}^{n} \sum_{j=1}^{n} u_{lk}^{*} u_{ji} \langle k|j\rangle =\\
# = \sum_{k=1}^{n} \sum_{j=1}^{n} u_{lk}^{*} u_{ji} \delta_{kj} =\\
# = \sum_{k=1}^{n} u_{lk}^{*} u_{ki} = \delta_{li}
# \end{equation}
#
# *where the unitary matrix condition has been used in the last step. We then have a set of $d \leq n$ orthonormal states. Selecting the other $n-d$ states satisfying the orthonormal condition as was stated before we get a basis of system A.*
#
# *For system B the same steps must be followed achieving the same result.* Q.E.D.

# %% [markdown]
# \begin{lemma}
# The Schmidt decomposition applies not only to bipartite systems but to any number of systems where we can make a bipartite cut of the systems. For example, suppose that there is a state $|\phi\rangle_{ABCDE}$ on systems ABCDE. We could say that AB are part of one system and CDE are part of another system and write a Schmidt decomposition for this state as follows:
#
# \begin{equation}
# |\phi\rangle_{ABCDE} = \sum_{y} \beta_y |y\rangle_{AB} |y\rangle_{CDE}
# \end{equation}
#
# where $\{|y\rangle_{AB}\}$ is an orthonormal basis for the joint system AB and $\{|y\rangle_{CDE}\}$ is an orthonormal basis for the joint system CDE.
# \end{lemma}

# %% [markdown]
# \begin{lemma}
# The Schmidt decomposition does not apply for partitions bigger than two. Suppose for example a three component quantum system ABC, then it can be shown that some quantum states $|\psi\rangle$ of this system can not be written in the form:
#
# \begin{equation}
# |\phi\rangle_{ABC} = \sum_{i} \lambda_i |i\rangle_A |i\rangle_B |i\rangle_C
# \end{equation}
#
# where $\lambda_i$ are real coefficients, and $|i\rangle_A$, $|i\rangle_B$ and $|i\rangle_C$ are orthonormal basis of the respective systems.
# \end{lemma}

# %% [markdown]
# \begin{corollary}
# Given a composite system AB, the reduced density operators $\rho_A$ and $\rho_B$ can be described in terms of the Schmidt coefficients and the basis $\{|i\rangle_A \}$ and $\{|i\rangle_B \}$.
# \end{corollary}
#
# **Proof.**
# *Starting with system A we remember that $dim(\mathscr{H}_A) = n$ and that we have defined $|i\rangle_A$ as:*
#
# \begin{equation}
# |i\rangle_A \equiv \sum_{j=1}^{n} u_{ji} |j\rangle_A
# \end{equation}
#
# *where $|j\rangle_A$ constitutes a basis of system A. Since $i$ varies from $1$ to $d$ we see that $dim(\{|i\rangle\}) = d$, where notation related to the system has been omitted. Lets see that this set satisfies the orthonormal relation:*
#
# \begin{equation}
# \langle l|i\rangle = \left( \sum_{k=1}^{n} u_{lk}^{*} \langle k|\right) \left(\sum_{j=1}^{n} u_{ji} |j\rangle \right) =\\
# = \sum_{k=1}^{n} \sum_{j=1}^{n} u_{lk}^{*} u_{ji} \langle k|j\rangle =\\
# = \sum_{k=1}^{n} \sum_{j=1}^{n} u_{lk}^{*} u_{ji} \delta_{kj} =\\
# = \sum_{k=1}^{n} u_{lk}^{*} u_{ki} = \delta_{li}
# \end{equation}
#
# *where the unitary matrix condition has been used in the last step. We then have a set of $d \leq n$ orthonormal states. Selecting the other $n-d$ states satisfying the orthonormal condition as was stated before we get a basis of system A.*
#
# *For system B the same steps must be followed achieving the same result.* Q.E.D.

# %% [markdown]
# ## Entropy

# %% [markdown]
# ## Application case: Ising model

# %%
import os
# %matplotlib inline

a = os.getcwd()
os.chdir(a[:42])

# %run "06 General Ising Model.ipynb"
# Out:
# <style>
# .output {
#     display: flex;
#     align-items: center;
#     text-align: center;
# }
# </style>
# C:\Users\javig\Anaconda3\envs\Qiskit\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\javig\Anaconda3\envs\Qiskit\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Failed to enable IBMQ account. Url:'https://quantumexperience.ng.bluemix.net/api' Token:'d99134c42331fe1359a22607643a0b8a604f5dc6e604e23eb7f8ffddc3ec5726df62bef7db896b4919994b3ad1cace1159784299c1da715f99c58264613f3582' Proxies:'{}' :Couldn't connect to IBMQ server: error during login: License required. You need to accept the License from Web Platform. https://quantumexperience.ng.bluemix.net
# Failed to enable IBMQ account. Url:'https://quantumexperience.ng.bluemix.net/api' Token:'d99134c42331fe1359a22607643a0b8a604f5dc6e604e23eb7f8ffddc3ec5726df62bef7db896b4919994b3ad1cace1159784299c1da715f99c58264613f3582' Proxies:'{}' :Couldn't connect to IBMQ server: error during login: License required. You need to accept the License from Web Platform. https://quantumexperience.ng.bluemix.net
# Failed to enable IBMQ account. Url:'https://quantumexperience.ng.bluemix.net/api' Token:'d99134c42331fe1359a22607643a0b8a604f5dc6e604e23eb7f8ffddc3ec5726df62bef7db896b4919994b3ad1cace1159784299c1da715f99c58264613f3582' Proxies:'{}' :Couldn't connect to IBMQ server: error during login: License required. You need to accept the License from Web Platform. https://quantumexperience.ng.bluemix.net
# Failed to enable IBMQ account. Url:'https://quantumexperience.ng.bluemix.net/api' Token:'d99134c42331fe1359a22607643a0b8a604f5dc6e604e23eb7f8ffddc3ec5726df62bef7db896b4919994b3ad1cace1159784299c1da715f99c58264613f3582' Proxies:'{}' :Couldn't connect to IBMQ server: error during login: License required. You need to accept the License from Web Platform. https://quantumexperience.ng.bluemix.net
# C:\Users\javig\Anaconda3\envs\Qiskit\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# {'num_optimizer_evals': 2874, 'min_val': -31.999999105730137, 'opt_params': array([-2.25473667e+00, -3.48990008e-01,  1.25310387e+00, -2.93670348e-03,
#        -3.69579218e-06, -8.51971986e-01, -2.78727571e+00, -1.16522255e+00,
#         3.14104058e+00, -2.81675155e+00, -2.93891948e-01, -2.97648388e-05,
#         1.28722896e+00,  1.76207599e+00,  3.79814207e-06,  9.67508380e-01,
#         1.86075111e+00, -3.00020313e+00, -5.04798181e-01,  8.38311200e-05,
#        -1.05253880e-04, -5.00233271e-01,  1.68881561e+00,  2.94991931e+00,
#        -9.48707788e-05, -2.91909282e+00, -2.13046107e-01, -4.84726610e-07,
#         2.46722828e+00,  6.64184158e-01, -3.24221308e-06, -2.43485887e+00,
#        -1.61989174e+00,  2.84895907e+00,  1.12109142e+00, -1.53096535e-03,
#        -3.14159265e+00,  5.17530414e-02, -2.47498612e+00, -3.92449400e-01,
#         5.63241567e-04,  8.93674127e-02, -5.04976956e-01,  3.14153968e+00,
#         4.22509866e-01,  1.89552354e+00, -2.76133668e+00,  1.46739998e+00,
#        -1.86082018e+00,  3.69038735e-01,  2.77774148e+00, -4.34144912e-03,
#        -3.14148118e+00,  2.72948882e+00, -1.63349608e+00, -1.30100651e+00,
#         7.44894765e-05,  2.03797530e-01,  2.70321117e+00,  3.14153206e+00,
#        -1.25307901e+00,  3.14159265e+00,  2.76132450e+00, -3.14156098e+00]), 'eval_time': 1718.6392948627472, 'eval_count': 2874, 'energy': -31.999999105730137, 'eigvals': array([-31.99999911]), 'min_vector': array([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j]), 'eigvecs': array([[0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j]])}
# The energy expected for the ground state is -32.000000 J (¿son julios realmente?) and the energy of the final state is -31.999999 J.
# This means that there is a relative error in the energy of the ground state of 2.79e-08 J, due to the noise registered by the population of other states.

# %%
par = []
with open("mis_fichero.txt", "r") as f:
    for line in f:
        par.append(float(line.strip()))
print('ya')
parameter = []

for i in range(0, len(par), len(result['opt_params'])):
    parameter.append(np.array(par[i:i + len(result['opt_params'])]))
    
print(parameter)
# Out:
# ya
# [array([-2.09981454,  0.36547548,  1.58628218,  1.05966443, -0.62737539,
#        -0.4243702 , -2.51975141, -1.55192284,  2.35136569, -2.41623984,
#        -1.3489967 , -0.09063675,  1.02592297,  0.74973912, -0.0086039 ,
#         1.16902097,  1.94423552, -1.8070023 , -1.04593333,  1.17126575,
#        -0.67044396, -2.13967658,  0.75552263,  2.39336866, -0.46083732,
#        -2.79268365,  0.829459  ,  1.05525708,  1.45867493,  0.95454789,
#        -0.14741107, -2.10159119, -1.53724373,  2.23610077,  1.59303447,
#        -0.56853992, -3.12831938, -0.20221689, -1.71606805, -0.48256598,
#         0.60053465, -0.80820735, -0.60188153,  2.90026837,  0.3080547 ,
#         0.58484602, -2.28833238,  1.5260429 , -2.6682576 , -0.05972616,
#         2.21519372,  0.69179453, -2.83065506,  3.14159265, -1.85948756,
#        -1.17869108,  0.05529073,  0.06270075,  2.56753532,  2.59463987,
#        -0.76077147,  2.59670665,  1.41308033, -1.66645402]), array([-2.23065047,  0.05789253,  2.03823447,  0.93814961,  0.18536254,
#        -0.98855678, -2.44545641, -1.56418003,  2.50627455, -2.77364925,
#        -1.0100736 , -0.4504388 ,  1.5330778 ,  1.36732319,  0.17093034,
#         1.01681379,  1.96153531, -2.849174  , -0.92496544,  0.70386861,
#        -0.63767429, -0.77566532,  0.85043713,  2.48447515,  0.08383239,
#        -2.48560467,  0.06685915,  0.30331197,  1.81848737,  0.99655471,
#        -0.18024494, -2.15735577, -1.40083077,  2.632196  ,  1.48713576,
#        -1.41293721, -3.14159265, -1.00755217, -2.3542952 , -1.10770465,
#         0.30715084, -0.24920823, -0.60101882,  2.84214836,  0.33792587,
#         1.02992804, -1.90318861,  1.44491501, -1.97038295,  0.21753925,
#         2.57860585,  0.63479092, -3.03498601,  3.14159265, -1.48889695,
#        -1.01618508, -0.12962763,  0.14854316,  3.11614599,  2.83262722,
#        -1.21242802,  2.8722276 ,  2.31000699, -2.08544552]), array([-2.56368332, -0.89115418,  1.25121021,  0.98852653,  1.41413428,
#        -1.31128609, -3.14159265, -1.2299184 ,  3.14159265, -2.48442991,
#        -0.02732147,  0.47110935,  3.14159265,  2.27494012,  0.16720956,
#         0.74659365,  1.79030409, -3.14159265, -1.37607585,  0.12651761,
#         0.53428029,  0.4726088 ,  1.42138144,  3.14159265,  0.36486015,
#        -3.14159265, -1.14715872, -1.19818783,  3.14159265,  1.10597348,
#        -0.27334495, -2.4449614 , -1.10002178,  3.14159265,  1.53244425,
#        -0.85471726, -3.13099286, -0.64351298, -2.53944551, -0.99130739,
#         0.37533637,  1.13446235, -1.05654668,  3.14159265,  1.12272816,
#         2.86896299, -2.23125176,  1.31939434, -1.07659712,  0.58828809,
#         3.14159265, -0.73866072, -3.14159265,  2.8085563 , -0.89175075,
#        -1.48120173, -0.03335522, -0.61336855,  3.14159265,  3.14159265,
#        -2.60646829,  3.14159265,  3.14159265, -3.14159265]), array([-2.22604642, -0.76911416,  0.26826561,  0.47658516,  0.12515962,
#        -0.84942231, -3.14159265, -0.51563446,  3.14159265, -3.14159265,
#        -0.2637762 ,  0.4092562 ,  0.97251895,  2.16039205, -0.50515975,
#         0.67986108,  1.91631641, -2.29186279, -1.30967776,  0.38708262,
#         1.28101058, -0.5469273 ,  2.31695249,  3.14159265, -0.30250447,
#        -2.47194662, -0.41569019, -0.81022504,  2.92215299,  1.5750037 ,
#        -0.12522648, -2.69594649, -1.78520114,  2.61482581,  0.97273337,
#         0.59297169, -3.14159265,  1.39667163, -1.73437812,  0.41675345,
#         0.74945216, -0.41549879, -0.47669804,  3.14159265,  0.29608672,
#         2.00195482, -3.07193176,  1.19764842, -1.97045519,  0.54716752,
#         2.94614873, -0.9274582 , -2.53706277,  2.3531256 , -1.07067258,
#        -2.77185242,  0.14735202,  0.63260323,  2.1623146 ,  3.14159265,
#        -1.22795396,  3.0064777 ,  2.43632057, -3.14159265]), array([-2.12794789, -0.66244686,  1.22325376, -0.95889352, -1.71234447,
#        -0.79259304, -2.80573614, -0.52733936,  2.98993679, -1.80764041,
#        -0.10622359,  0.2510658 ,  0.78213498,  1.52314792, -0.77552678,
#         1.34601168,  1.88363539, -2.826831  , -0.39964275, -0.36177102,
#        -0.35584885, -1.26956413,  1.85411978,  3.14159265, -0.54717399,
#        -3.14159265, -0.13725025,  0.21819927,  2.2959136 ,  0.48794398,
#         0.35995194, -2.10459198, -2.10609032,  2.4231907 , -0.06054027,
#         0.23099525, -3.14159265,  1.99158109, -2.31536473,  0.13352354,
#         0.38458727,  0.68964939, -0.50839528,  3.14159265, -0.22480404,
#         2.78353246, -3.14159265,  1.88304255, -2.22706299,  0.55730227,
#         2.27282934,  0.65547541, -3.14159265,  1.82028638, -1.65254974,
#        -2.70018261,  0.37780769, -0.41439134,  2.38927145,  3.14159265,
#        -0.50418459,  3.14159265,  2.35695089, -3.14159265]), array([-2.50943503, -0.10151602,  0.8973695 , -0.50512053, -1.08176756,
#        -0.32122678, -1.67634896, -1.85478279,  2.70612698, -3.07652621,
#        -0.06129284, -0.08351406,  1.1901681 ,  1.97505479,  0.01615692,
#         1.61754735,  1.47580227, -3.14159265, -0.4564017 ,  0.15642575,
#        -0.46382836, -1.72049124,  1.36808693,  2.34859153, -0.37873471,
#        -2.67499327, -0.01300422,  1.06502065,  1.7794532 , -0.32245441,
#         0.30510305, -1.90882397, -1.51847726,  2.82949885,  0.72103798,
#         0.85199147, -3.14159265,  0.23084858, -3.14159265, -0.81215803,
#        -0.26032478, -0.54914503, -0.65775848,  3.14159265,  0.61836697,
#         1.64950669, -3.14159265,  2.12079377, -1.84015813,  0.51813935,
#         2.37773571,  0.02693071, -3.14159265,  2.56606348, -1.86838118,
#        -1.05621152,  0.7137535 ,  0.61090052,  2.83173226,  3.14159265,
#        -1.25700732,  3.14159265,  1.96569586, -3.14159265]), array([-2.23289972, -0.0237268 ,  0.99694367, -0.31531866,  0.31452405,
#        -1.4003675 , -2.76215455, -1.54816703,  3.09196322, -2.79991806,
#        -0.24073706, -0.79557961,  1.04402021,  1.74999205,  0.04639028,
#         0.8293869 ,  1.75586514, -3.14159265, -0.33746999, -0.16700722,
#        -0.09982816, -0.42741688,  1.17268401,  2.52553181, -0.51724019,
#        -3.14159265,  0.16394978,  0.63899067,  2.4552012 , -0.013     ,
#         0.07463729, -2.6938539 , -1.57933671,  2.99737661,  1.26929897,
#         0.2146047 , -2.75789148, -0.58370893, -2.1353385 , -0.28563412,
#        -0.16480843,  0.07165881, -0.56438425,  3.14159265, -0.07136912,
#         1.14375091, -2.7941479 ,  1.34641358, -1.91202895,  0.40895603,
#         2.60206213,  0.13369069, -3.14159265,  3.14159265, -2.37309911,
#        -0.25799701,  0.38352709,  0.13392148,  2.80257118,  3.14159265,
#        -0.81824131,  3.14159265,  2.7329702 , -2.77531458]), array([-1.93736862, -0.36265814,  1.42186318,  0.03067203,  0.34103901,
#        -1.25111161, -2.94863438, -0.87538051,  3.14159265, -3.14159265,
#        -0.31869303, -0.10327002,  1.75713845,  1.67052939,  0.01043506,
#         1.09372838,  2.08351523, -3.1350479 ,  0.02913823, -0.17885482,
#        -0.63289828,  0.26649793,  2.02478933,  3.05593619, -0.26570299,
#        -2.8887411 ,  0.10354977,  0.01004522,  2.65517102,  0.66802644,
#        -0.1243236 , -2.39784195, -1.79922565,  2.87860529,  1.28459318,
#        -0.23502999, -3.14159265, -0.31124238, -2.33499418, -0.67305183,
#         0.0535113 , -0.1819375 , -0.35926393,  3.1388607 ,  0.64528005,
#         1.78341323, -2.41425684,  1.58307712, -2.05376847,  0.05808745,
#         2.66449575, -0.0201641 , -3.14159265,  3.09129596, -1.58525854,
#        -1.1551914 ,  0.11252425,  0.59019786,  2.58836758,  3.14159265,
#        -1.47512087,  3.03818456,  3.14159265, -3.14159265]), array([-2.40205265e+00, -3.14457220e-01,  1.33589293e+00,  1.74000288e-01,
#         4.68535297e-01, -6.25892494e-01, -2.59632184e+00, -8.43826227e-01,
#         3.04532164e+00, -2.69909252e+00, -1.03815201e-01,  1.45737470e-01,
#         1.14310520e+00,  1.77385347e+00,  2.33785102e-01,  7.97177842e-01,
#         1.71012588e+00, -3.00593686e+00, -2.77021115e-01, -5.77214484e-02,
#        -4.03337824e-01, -2.45708221e-01,  2.25401754e+00,  2.99372245e+00,
#         1.59571370e-01, -3.14159265e+00, -2.40429071e-01, -4.00581764e-01,
#         2.74361369e+00,  1.04055366e+00, -8.94585690e-02, -2.61510979e+00,
#        -1.36751994e+00,  2.97119591e+00,  1.46883952e+00, -3.57328866e-01,
#        -3.04386603e+00, -2.81887861e-01, -2.82118940e+00, -7.70488995e-01,
#         7.19254901e-02,  3.94594052e-01, -5.33301216e-01,  2.89548096e+00,
#         4.84653814e-01,  1.60127827e+00, -2.56059266e+00,  1.27411456e+00,
#        -1.60362871e+00,  1.57315775e-01,  3.01513300e+00,  1.82076000e-04,
#        -2.92440211e+00,  2.55636844e+00, -1.25714828e+00, -1.46460062e+00,
#        -6.01810450e-03,  1.99062351e-01,  2.69133178e+00,  3.01568308e+00,
#        -1.27500554e+00,  3.06068761e+00,  3.08991812e+00, -2.95208906e+00]), array([-2.33173101, -0.18498396,  1.37849572,  0.27413434,  0.209243  ,
#        -0.70122674, -3.07971577, -1.0076713 ,  2.99655233, -2.78853542,
#        -0.13269188, -0.07471956,  1.38180952,  1.64202823,  0.27734307,
#         0.92506043,  1.80538244, -2.97470456, -0.51466618,  0.09164914,
#        -0.30847968, -0.52892514,  1.63172258,  2.82660213,  0.25589533,
#        -2.87434894, -0.33318021, -0.32073339,  2.3053632 ,  0.78550919,
#         0.01062691, -2.44369556, -1.50153483,  2.80734563,  1.2926478 ,
#        -0.2273415 , -3.11525482, -0.03722214, -2.24988571, -0.22046271,
#         0.15127262,  0.22997247, -0.54144143,  3.10544502,  0.69530646,
#         2.09177674, -2.71986724,  1.40766219, -1.68982452,  0.41529537,
#         3.02968211,  0.00649592, -2.83616854,  2.42266453, -1.73243067,
#        -1.29790526, -0.09516515,  0.30525475,  2.67503753,  3.14159265,
#        -1.44285717,  3.14159265,  2.83118952, -3.02005594]), array([-2.15423073, -0.39624781,  1.29097517,  0.28796722,  0.04724236,
#        -0.90096064, -2.7688852 , -1.17824357,  3.11590406, -2.71003454,
#        -0.27947025,  0.23788314,  1.20519769,  1.68493929,  0.05863254,
#         1.01843292,  1.98423558, -2.94788507, -0.61549401,  0.11929791,
#        -0.16199865, -0.40748426,  1.57102818,  2.76118943,  0.02968558,
#        -2.90946228, -0.21389686,  0.01366073,  2.47102988,  0.75562107,
#         0.0175741 , -2.37339899, -1.7044949 ,  2.87147284,  1.13609564,
#         0.02724117, -3.1188848 ,  0.14347859, -2.50181965, -0.48530457,
#         0.22099785,  0.19712441, -0.47257478,  3.13199299,  0.46316338,
#         2.00436674, -2.75827181,  1.51338787, -1.96093518,  0.393038  ,
#         2.91764942, -0.11285842, -2.82752666,  2.70008656, -1.73288927,
#        -1.21456494, -0.14813658,  0.17980195,  2.62275682,  3.14159265,
#        -1.23971048,  3.12406739,  2.77073439, -3.14159265]), array([-2.2695535 , -0.48769005,  1.24839226,  0.02668646, -0.07646512,
#        -0.84637974, -2.73481041, -1.13849397,  3.04111061, -2.8092412 ,
#        -0.27286934,  0.04237259,  1.27458675,  1.75813551, -0.05814221,
#         0.965208  ,  1.87409317, -3.03203463, -0.60484279, -0.04293546,
#        -0.15641209, -0.52153507,  1.66324879,  2.8505715 , -0.05244453,
#        -2.84799808, -0.22891114, -0.01394618,  2.5429038 ,  0.70205565,
#         0.00673862, -2.446464  , -1.5799586 ,  2.95962352,  1.08267454,
#        -0.1021025 , -3.14159265,  0.23795666, -2.43125389, -0.37986422,
#         0.08740604,  0.07512098, -0.52175501,  3.14159265,  0.42691135,
#         1.92025198, -2.81372749,  1.46662119, -1.87491159,  0.34709638,
#         2.81384896,  0.04207943, -2.96344246,  2.74342615, -1.68824483,
#        -1.29870633, -0.07967698,  0.21071217,  2.71064405,  3.14159265,
#        -1.25259421,  3.14159265,  2.72416436, -3.14159265]), array([-2.22166051, -0.36218359,  1.30881668,  0.05021355, -0.07796219,
#        -0.8089668 , -2.67286857, -1.09115052,  3.03287335, -2.77090269,
#        -0.32774223, -0.07414721,  1.28632448,  1.7739401 , -0.12818044,
#         0.95609442,  1.89728422, -3.12773559, -0.53935636,  0.03876636,
#        -0.10370827, -0.56613723,  1.74508387,  2.86785765, -0.00923441,
#        -2.89177888, -0.19927301, -0.04322868,  2.51165181,  0.64325205,
#        -0.01850808, -2.45870567, -1.62834923,  2.84489906,  1.00498287,
#         0.01715753, -3.14159265,  0.17600612, -2.43679804, -0.35189371,
#         0.03682189,  0.09544019, -0.4899674 ,  3.14159265,  0.43612646,
#         1.91745618, -2.79643783,  1.45953444, -1.87305831,  0.42276822,
#         2.73316662, -0.026179  , -2.95919681,  2.75152615, -1.64942348,
#        -1.38503799, -0.0554182 ,  0.14387707,  2.69658331,  3.14159265,
#        -1.26894667,  3.14159265,  2.75512185, -3.14159265]), array([-2.24920752e+00, -3.09182648e-01,  1.23589067e+00, -6.37677000e-04,
#        -1.51908466e-02, -8.66888898e-01, -2.72742187e+00, -1.06083684e+00,
#         3.09375297e+00, -2.78980129e+00, -2.90287160e-01,  2.30430325e-02,
#         1.27721801e+00,  1.74985090e+00, -3.15113310e-02,  1.00460051e+00,
#         1.84595200e+00, -2.98651022e+00, -5.29110560e-01,  2.73401444e-02,
#        -1.38950594e-01, -5.03530010e-01,  1.71540769e+00,  2.86229304e+00,
#        -6.62871330e-03, -2.89133920e+00, -1.99664653e-01,  1.95935466e-02,
#         2.48129187e+00,  6.21989626e-01, -1.15833252e-02, -2.40852085e+00,
#        -1.60834242e+00,  2.85012297e+00,  1.09511790e+00, -3.10191669e-02,
#        -3.14103508e+00,  5.95019399e-02, -2.40981847e+00, -3.94478135e-01,
#         1.03546920e-01,  8.15558051e-02, -5.15738977e-01,  3.14159265e+00,
#         4.08928149e-01,  1.89262240e+00, -2.77544436e+00,  1.50664743e+00,
#        -1.84163461e+00,  4.00760481e-01,  2.77666107e+00,  2.68452352e-02,
#        -2.98534847e+00,  2.71433861e+00, -1.66950224e+00, -1.39110929e+00,
#         2.63598551e-02,  1.84349468e-01,  2.70655794e+00,  3.14159265e+00,
#        -1.23890332e+00,  3.14159265e+00,  2.73764589e+00, -3.14159265e+00]), array([-2.22957224, -0.3449821 ,  1.23432947,  0.01776577, -0.02100825,
#        -0.85517171, -2.75199975, -1.10161969,  3.07221159, -2.78976965,
#        -0.28810529,  0.00431577,  1.28760412,  1.7579293 , -0.00491802,
#         0.96320206,  1.84905316, -2.94011211, -0.50594992,  0.03422824,
#        -0.16961205, -0.50541351,  1.68801557,  2.84182163, -0.01182479,
#        -2.90042094, -0.19195127,  0.00927635,  2.47735578,  0.6383491 ,
#         0.01256353, -2.44922457, -1.63382113,  2.8286601 ,  1.1031201 ,
#        -0.00880236, -3.14159265,  0.07855261, -2.42682176, -0.41958644,
#         0.05845811,  0.07967838, -0.51647022,  3.14159265,  0.42405599,
#         1.88085861, -2.76360681,  1.46397071, -1.86785902,  0.33510233,
#         2.77196735,  0.01365721, -3.00925056,  2.68226116, -1.67094213,
#        -1.34206309,  0.03639271,  0.19085209,  2.70127014,  3.14159265,
#        -1.25023536,  3.14159265,  2.7415241 , -3.10839294]), array([-2.23609769, -0.33464024,  1.24012075,  0.00902412,  0.01294894,
#        -0.84519113, -2.76124464, -1.12387552,  3.10399199, -2.80452079,
#        -0.28419111, -0.01452056,  1.29483199,  1.74595291,  0.01289644,
#         0.98415282,  1.84306231, -2.98422956, -0.49661509,  0.00641069,
#        -0.14127432, -0.49686611,  1.67743133,  2.85050507, -0.02345658,
#        -2.90496996, -0.20207565, -0.01012793,  2.48358611,  0.6465956 ,
#         0.01187206, -2.4270673 , -1.62669366,  2.81288415,  1.11004086,
#        -0.01759323, -3.12464027,  0.10464181, -2.45309546, -0.43646614,
#         0.03254444,  0.07947429, -0.51774542,  3.14159265,  0.41413603,
#         1.88747339, -2.74978089,  1.48442888, -1.85164438,  0.33666773,
#         2.77440575,  0.01964388, -2.98944676,  2.66972931, -1.66541019,
#        -1.31031049,  0.00884746,  0.19715412,  2.71302288,  3.14159265,
#        -1.24294399,  3.14159265,  2.761724  , -3.14159265]), array([-2.25586755e+00, -3.18934286e-01,  1.24150458e+00,  2.57201266e-02,
#        -9.82368040e-03, -8.62205006e-01, -2.75724827e+00, -1.12922650e+00,
#         3.12317832e+00, -2.80453504e+00, -2.95690691e-01,  2.89585200e-03,
#         1.29405141e+00,  1.76135789e+00,  1.34341340e-02,  9.71781155e-01,
#         1.84534704e+00, -2.99615429e+00, -5.03349146e-01, -4.97454200e-04,
#        -1.60318117e-01, -4.92625720e-01,  1.67750673e+00,  2.85120536e+00,
#        -2.86653783e-02, -2.91538533e+00, -1.91310544e-01,  3.90668210e-03,
#         2.47302831e+00,  6.59377317e-01, -2.66610220e-03, -2.43784119e+00,
#        -1.60358922e+00,  2.84610494e+00,  1.11260756e+00, -5.26534400e-03,
#        -3.14159265e+00,  1.01012627e-01, -2.44590326e+00, -4.13951088e-01,
#         1.72113587e-02,  8.40125744e-02, -5.04799074e-01,  3.14159265e+00,
#         4.28226029e-01,  1.86907114e+00, -2.74447832e+00,  1.47094481e+00,
#        -1.84275939e+00,  3.78140252e-01,  2.77694129e+00,  9.55004520e-03,
#        -3.00799644e+00,  2.69371946e+00, -1.66331928e+00, -1.30558361e+00,
#        -1.00154090e-02,  1.97445987e-01,  2.69886320e+00,  3.14159265e+00,
#        -1.25476429e+00,  3.14159265e+00,  2.76533923e+00, -3.14159265e+00]), array([-2.24675309e+00, -3.43336961e-01,  1.24851352e+00,  1.86146968e-02,
#         5.27132480e-03, -8.67106690e-01, -2.73243338e+00, -1.12082624e+00,
#         3.13789938e+00, -2.81516005e+00, -2.86119012e-01,  6.13378280e-03,
#         1.30481151e+00,  1.74155118e+00,  1.90261341e-02,  9.59990078e-01,
#         1.86986978e+00, -3.01070985e+00, -5.02318540e-01, -1.13999581e-02,
#        -1.40005673e-01, -4.99339182e-01,  1.67905335e+00,  2.86549128e+00,
#        -7.43060100e-04, -2.91925833e+00, -2.06079940e-01,  9.10740820e-03,
#         2.45907344e+00,  6.54628632e-01, -5.15862700e-03, -2.44772742e+00,
#        -1.61155891e+00,  2.87086458e+00,  1.11155100e+00, -3.11192960e-03,
#        -3.13530550e+00,  7.10573286e-02, -2.45621328e+00, -4.00405044e-01,
#        -1.60387987e-02,  8.22390117e-02, -5.13457120e-01,  3.14159265e+00,
#         4.27705239e-01,  1.88610144e+00, -2.75557834e+00,  1.45825017e+00,
#        -1.86463478e+00,  3.80694989e-01,  2.77752521e+00,  1.82291644e-02,
#        -2.99489931e+00,  2.71387892e+00, -1.66500909e+00, -1.31436250e+00,
#        -1.16925689e-02,  2.04863575e-01,  2.71252569e+00,  3.14159265e+00,
#        -1.25329132e+00,  3.14159265e+00,  2.75804817e+00, -3.14159265e+00]), array([-2.25167833e+00, -3.72758597e-01,  1.24490761e+00,  2.15380236e-02,
#         4.47806870e-03, -8.75330223e-01, -2.73533865e+00, -1.12020495e+00,
#         3.14159265e+00, -2.81055309e+00, -2.85206843e-01, -1.31399221e-02,
#         1.29505222e+00,  1.76045796e+00,  2.90305130e-03,  9.80016305e-01,
#         1.86401642e+00, -3.02461167e+00, -5.15029659e-01,  3.87379980e-03,
#        -1.45215611e-01, -5.00275018e-01,  1.67726592e+00,  2.86447858e+00,
#         1.95502283e-02, -2.92354447e+00, -2.05810920e-01, -2.72437770e-03,
#         2.47107255e+00,  6.68603406e-01,  2.24370060e-03, -2.42682354e+00,
#        -1.60915058e+00,  2.86509686e+00,  1.11752355e+00,  6.25677710e-03,
#        -3.14159265e+00,  6.05344425e-02, -2.44361056e+00, -3.88273907e-01,
#        -1.98740900e-04,  8.85049800e-02, -5.13265196e-01,  3.14159265e+00,
#         4.28806369e-01,  1.87090541e+00, -2.75102005e+00,  1.47845300e+00,
#        -1.86509782e+00,  3.54554245e-01,  2.78395893e+00,  1.58571454e-02,
#        -3.00347985e+00,  2.72087070e+00, -1.66452190e+00, -1.31916118e+00,
#         2.59552810e-03,  2.02696211e-01,  2.71053167e+00,  3.14159265e+00,
#        -1.25493977e+00,  3.14159265e+00,  2.76084179e+00, -3.14159265e+00]), array([-2.24953398e+00, -3.47766363e-01,  1.25026520e+00,  1.30914686e-02,
#         8.09991040e-03, -8.65037517e-01, -2.74225155e+00, -1.12473043e+00,
#         3.14159265e+00, -2.81070572e+00, -2.93638188e-01,  2.56600500e-03,
#         1.29745783e+00,  1.75101162e+00, -9.62388740e-03,  9.65353903e-01,
#         1.85767878e+00, -3.00618008e+00, -5.08084549e-01,  8.09428070e-03,
#        -1.42514943e-01, -5.05658972e-01,  1.68001585e+00,  2.85999713e+00,
#         7.62707450e-03, -2.91449596e+00, -1.93660968e-01,  6.77574600e-04,
#         2.47695614e+00,  6.59933245e-01,  6.52261930e-03, -2.44239544e+00,
#        -1.61199679e+00,  2.85100938e+00,  1.11241312e+00,  5.69667400e-04,
#        -3.13854484e+00,  8.00163414e-02, -2.44400498e+00, -4.01855465e-01,
#         1.96128021e-02,  8.07664921e-02, -5.06135957e-01,  3.14159265e+00,
#         4.25654560e-01,  1.88482397e+00, -2.75747599e+00,  1.46447076e+00,
#        -1.85930355e+00,  3.63266844e-01,  2.77515064e+00,  2.34763754e-02,
#        -3.00176023e+00,  2.70819572e+00, -1.66017482e+00, -1.31900832e+00,
#         5.75734500e-03,  2.05192966e-01,  2.69866510e+00,  3.14159265e+00,
#        -1.25184547e+00,  3.13776474e+00,  2.75262476e+00, -3.14132550e+00]), array([-2.24551745e+00, -3.39747634e-01,  1.24916496e+00,  1.21195533e-02,
#         7.91255350e-03, -8.68155945e-01, -2.75108671e+00, -1.12067520e+00,
#         3.14159265e+00, -2.81116766e+00, -2.84884048e-01,  6.62199900e-04,
#         1.29179375e+00,  1.75751961e+00, -9.87634760e-03,  9.68037599e-01,
#         1.86092893e+00, -2.99776960e+00, -5.08250872e-01,  6.02571020e-03,
#        -1.37732697e-01, -4.96620505e-01,  1.68198722e+00,  2.87146694e+00,
#         8.22704690e-03, -2.91503324e+00, -2.04765380e-01, -5.00419070e-03,
#         2.48141187e+00,  6.58716240e-01, -3.16770810e-03, -2.43902266e+00,
#        -1.61769004e+00,  2.84956607e+00,  1.11608321e+00,  8.70781190e-03,
#        -3.14159265e+00,  8.95167764e-02, -2.44364696e+00, -4.08667687e-01,
#        -1.22098700e-03,  8.21996609e-02, -5.14829130e-01,  3.14159265e+00,
#         4.23841230e-01,  1.88293084e+00, -2.76181845e+00,  1.46762393e+00,
#        -1.86094117e+00,  3.69380452e-01,  2.77659245e+00,  2.05329361e-02,
#        -3.00977216e+00,  2.70798186e+00, -1.65911938e+00, -1.32572916e+00,
#         7.69814600e-04,  2.05227674e-01,  2.70730644e+00,  3.14159265e+00,
#        -1.25139944e+00,  3.14159265e+00,  2.75118640e+00, -3.14159265e+00]), array([-2.24673304e+00, -3.45499165e-01,  1.24500902e+00,  1.14292208e-02,
#         3.83980080e-03, -8.61972196e-01, -2.75321744e+00, -1.12166469e+00,
#         3.14159265e+00, -2.80774650e+00, -2.93408692e-01, -8.63196400e-04,
#         1.29150263e+00,  1.75457224e+00, -6.29436630e-03,  9.71654084e-01,
#         1.85823666e+00, -2.98690068e+00, -5.08878024e-01, -4.70729630e-03,
#        -1.27902147e-01, -5.02477939e-01,  1.68898018e+00,  2.86896388e+00,
#        -3.30059720e-03, -2.91747368e+00, -1.97034146e-01, -1.11068870e-03,
#         2.47591595e+00,  6.53010685e-01, -6.98643600e-03, -2.43547741e+00,
#        -1.61856375e+00,  2.84956758e+00,  1.11770184e+00,  1.07011851e-02,
#        -3.14159265e+00,  7.89413091e-02, -2.44088070e+00, -4.04137311e-01,
#        -1.05128947e-02,  8.29296770e-02, -5.07045489e-01,  3.14159265e+00,
#         4.25385444e-01,  1.88659826e+00, -2.75719889e+00,  1.47126814e+00,
#        -1.86305370e+00,  3.61283216e-01,  2.77615938e+00,  1.93029211e-02,
#        -3.00888928e+00,  2.70391310e+00, -1.65436803e+00, -1.32834629e+00,
#        -9.79430970e-03,  2.01847136e-01,  2.69845014e+00,  3.14159265e+00,
#        -1.25225199e+00,  3.14159265e+00,  2.75560903e+00, -3.14159265e+00]), array([-2.24764454e+00, -3.45766988e-01,  1.24640059e+00,  1.56409461e-02,
#        -3.73651140e-03, -8.62265600e-01, -2.75123902e+00, -1.11885732e+00,
#         3.14159265e+00, -2.80927262e+00, -2.86520815e-01,  2.83340000e-05,
#         1.29319191e+00,  1.75275432e+00,  3.32841860e-03,  9.68034824e-01,
#         1.85735391e+00, -3.00224797e+00, -5.07633422e-01, -5.76002900e-03,
#        -1.31134661e-01, -4.99711413e-01,  1.68533971e+00,  2.87137445e+00,
#        -6.12629410e-03, -2.91447438e+00, -2.03542253e-01,  1.01208980e-03,
#         2.47669354e+00,  6.55648150e-01,  2.90914520e-03, -2.43947501e+00,
#        -1.61680518e+00,  2.84610999e+00,  1.11367116e+00,  6.78276680e-03,
#        -3.14159265e+00,  7.40781675e-02, -2.44451093e+00, -4.07402878e-01,
#         4.20810460e-03,  8.35818448e-02, -5.12540598e-01,  3.14159265e+00,
#         4.23319456e-01,  1.88593010e+00, -2.75519813e+00,  1.46762326e+00,
#        -1.85974150e+00,  3.61975165e-01,  2.77401854e+00,  1.36308650e-02,
#        -3.01273017e+00,  2.70329777e+00, -1.65970564e+00, -1.32605225e+00,
#        -8.04797610e-03,  2.03671721e-01,  2.70542385e+00,  3.14159265e+00,
#        -1.25107688e+00,  3.14159265e+00,  2.75747834e+00, -3.14085003e+00]), array([-2.24739391e+00, -3.45025881e-01,  1.24636550e+00,  9.80597570e-03,
#        -2.77505300e-03, -8.61889875e-01, -2.75232606e+00, -1.12288450e+00,
#         3.14159265e+00, -2.80835493e+00, -2.89357525e-01,  4.95444000e-04,
#         1.29432386e+00,  1.75497191e+00,  6.65273840e-03,  9.69981735e-01,
#         1.86013701e+00, -3.00084964e+00, -5.05099983e-01, -3.12458580e-03,
#        -1.25569433e-01, -4.98589409e-01,  1.68486633e+00,  2.87217770e+00,
#         3.75313470e-03, -2.91667876e+00, -2.01467591e-01,  1.14098690e-03,
#         2.47556131e+00,  6.58565484e-01,  3.28125110e-03, -2.43766049e+00,
#        -1.61659387e+00,  2.85148000e+00,  1.11249614e+00,  4.78391480e-03,
#        -3.14159265e+00,  7.94465134e-02, -2.44675952e+00, -4.06324549e-01,
#         4.47678500e-04,  8.48814399e-02, -5.09858836e-01,  3.14159265e+00,
#         4.26204705e-01,  1.88273405e+00, -2.75521594e+00,  1.46935774e+00,
#        -1.86163140e+00,  3.66173700e-01,  2.77234592e+00,  1.65346169e-02,
#        -3.01200237e+00,  2.70580487e+00, -1.65944947e+00, -1.32088250e+00,
#        -3.01811000e-05,  2.01688044e-01,  2.70312486e+00,  3.14159265e+00,
#        -1.25365895e+00,  3.14159265e+00,  2.75767645e+00, -3.14159265e+00]), array([-2.24988729e+00, -3.45775630e-01,  1.24339537e+00,  7.62591440e-03,
#        -3.30888810e-03, -8.62043977e-01, -2.75272404e+00, -1.12641361e+00,
#         3.14159265e+00, -2.80975281e+00, -2.89195409e-01, -7.81810200e-04,
#         1.29494895e+00,  1.74909175e+00,  2.51192710e-03,  9.69630631e-01,
#         1.85884967e+00, -3.00221386e+00, -5.06657876e-01,  1.12054390e-03,
#        -1.23130155e-01, -4.97257140e-01,  1.68516747e+00,  2.87443541e+00,
#         6.15519830e-03, -2.91603657e+00, -2.02986894e-01, -3.56994600e-04,
#         2.47346615e+00,  6.56918572e-01, -7.96137000e-05, -2.43784452e+00,
#        -1.61468566e+00,  2.85336432e+00,  1.11506431e+00,  7.38026770e-03,
#        -3.14159265e+00,  7.91572749e-02, -2.45021443e+00, -4.05923674e-01,
#        -2.14918180e-03,  8.46005007e-02, -5.09872488e-01,  3.14159265e+00,
#         4.22912658e-01,  1.88777455e+00, -2.75154318e+00,  1.46899211e+00,
#        -1.86020662e+00,  3.66797467e-01,  2.77427295e+00,  1.51838272e-02,
#        -3.02009147e+00,  2.70763099e+00, -1.65808194e+00, -1.31728761e+00,
#         1.44007350e-03,  2.02189082e-01,  2.70427792e+00,  3.14159265e+00,
#        -1.25067092e+00,  3.14159265e+00,  2.76233400e+00, -3.14159265e+00]), array([-2.24841563e+00, -3.45531410e-01,  1.24530673e+00,  7.78946350e-03,
#         2.88052380e-03, -8.62109652e-01, -2.75141692e+00, -1.12628351e+00,
#         3.14159265e+00, -2.80931199e+00, -2.88958067e-01,  1.31668200e-04,
#         1.29446175e+00,  1.75393335e+00, -2.98741900e-04,  9.69469352e-01,
#         1.85932220e+00, -3.00122132e+00, -5.06238714e-01,  2.25412810e-03,
#        -1.23868907e-01, -4.99883714e-01,  1.68377038e+00,  2.87490775e+00,
#         1.97640900e-04, -2.91616320e+00, -2.02815755e-01, -3.20069700e-04,
#         2.47274741e+00,  6.58412517e-01, -3.09001080e-03, -2.43785802e+00,
#        -1.61622388e+00,  2.85041363e+00,  1.11490366e+00,  5.71694010e-03,
#        -3.14159265e+00,  7.75350712e-02, -2.44997560e+00, -4.03997476e-01,
#         7.31907300e-04,  8.46062218e-02, -5.10369326e-01,  3.14159265e+00,
#         4.25417159e-01,  1.88424254e+00, -2.75733985e+00,  1.46881012e+00,
#        -1.86112280e+00,  3.65326885e-01,  2.77468397e+00,  1.69497530e-02,
#        -3.02138986e+00,  2.70806903e+00, -1.65845290e+00, -1.31783043e+00,
#        -2.29137750e-03,  2.02329864e-01,  2.70426532e+00,  3.14159265e+00,
#        -1.25292105e+00,  3.14150358e+00,  2.75616430e+00, -3.14159265e+00]), array([-2.25110834e+00, -3.45927446e-01,  1.24790821e+00,  8.56465390e-03,
#         7.91085920e-03, -8.62466086e-01, -2.75419478e+00, -1.12918571e+00,
#         3.14159265e+00, -2.81096195e+00, -2.89859582e-01,  1.55305180e-03,
#         1.29362033e+00,  1.75492731e+00, -3.82094640e-03,  9.70135914e-01,
#         1.85759842e+00, -3.00010270e+00, -5.04149062e-01, -5.50037800e-04,
#        -1.14406786e-01, -4.99888272e-01,  1.68336086e+00,  2.88209149e+00,
#         8.26687800e-04, -2.91608204e+00, -2.03854240e-01,  9.09280900e-04,
#         2.47306219e+00,  6.60030541e-01,  2.65176930e-03, -2.43662989e+00,
#        -1.61469156e+00,  2.85102095e+00,  1.11453763e+00,  8.54691490e-03,
#        -3.14159265e+00,  7.46370630e-02, -2.45233747e+00, -4.01352690e-01,
#        -4.55447330e-03,  8.43223705e-02, -5.09653154e-01,  3.14159265e+00,
#         4.24285651e-01,  1.88569808e+00, -2.75945232e+00,  1.46955831e+00,
#        -1.85928596e+00,  3.65537276e-01,  2.77396394e+00,  1.35525296e-02,
#        -3.03222844e+00,  2.71052593e+00, -1.65679021e+00, -1.31624103e+00,
#        -2.30691480e-03,  2.02836707e-01,  2.70451726e+00,  3.14159265e+00,
#        -1.25217529e+00,  3.14159265e+00,  2.75576084e+00, -3.14159265e+00]), array([-2.24869500e+00, -3.43917569e-01,  1.24568510e+00,  8.95708950e-03,
#         5.69816760e-03, -8.61587027e-01, -2.75576113e+00, -1.13234746e+00,
#         3.14159265e+00, -2.81139978e+00, -2.90415718e-01, -1.85935600e-03,
#         1.29337157e+00,  1.75637011e+00, -3.56049220e-03,  9.69663562e-01,
#         1.86036860e+00, -3.00028944e+00, -5.08078767e-01, -5.83614440e-03,
#        -1.07912262e-01, -5.00943418e-01,  1.68522801e+00,  2.88561146e+00,
#         1.42547350e-03, -2.91617151e+00, -2.03553246e-01,  8.53301800e-04,
#         2.47335249e+00,  6.59877631e-01,  4.18079310e-03, -2.43673034e+00,
#        -1.61744089e+00,  2.85001990e+00,  1.11888026e+00,  6.83391370e-03,
#        -3.14159265e+00,  7.36463401e-02, -2.45397557e+00, -4.01075192e-01,
#        -1.05326290e-03,  8.44276089e-02, -5.09197985e-01,  3.14159265e+00,
#         4.24191746e-01,  1.88618080e+00, -2.75960945e+00,  1.46917343e+00,
#        -1.86151214e+00,  3.67981373e-01,  2.77799488e+00,  1.24531993e-02,
#        -3.03957815e+00,  2.71121240e+00, -1.65258604e+00, -1.31596822e+00,
#         1.72932000e-05,  2.03194051e-01,  2.70399128e+00,  3.14159265e+00,
#        -1.25228087e+00,  3.14159265e+00,  2.75583712e+00, -3.14037293e+00]), array([-2.25045533e+00, -3.46343135e-01,  1.24967434e+00,  8.30976650e-03,
#         2.78879540e-03, -8.61280322e-01, -2.75985353e+00, -1.13495985e+00,
#         3.14159265e+00, -2.81216972e+00, -2.90140578e-01, -1.84740420e-03,
#         1.29205323e+00,  1.75750882e+00, -1.21599360e-03,  9.69398544e-01,
#         1.85924904e+00, -2.99881547e+00, -5.06097691e-01, -5.07796360e-03,
#        -9.54970743e-02, -5.00955216e-01,  1.68462453e+00,  2.89262323e+00,
#         1.36251610e-03, -2.91623786e+00, -2.04288964e-01,  1.32967520e-03,
#         2.47268507e+00,  6.58843212e-01, -2.16190680e-03, -2.43652472e+00,
#        -1.61640887e+00,  2.85088654e+00,  1.11723543e+00,  7.94362240e-03,
#        -3.14159265e+00,  7.24541219e-02, -2.45486554e+00, -4.01249325e-01,
#         2.37912360e-03,  8.44857036e-02, -5.09489027e-01,  3.14159265e+00,
#         4.23888448e-01,  1.88647354e+00, -2.75776967e+00,  1.46896937e+00,
#        -1.86079772e+00,  3.66344600e-01,  2.77604072e+00,  1.03731347e-02,
#        -3.04584647e+00,  2.71297689e+00, -1.65100123e+00, -1.31565426e+00,
#         1.38518290e-03,  2.03979434e-01,  2.70398748e+00,  3.14159265e+00,
#        -1.25206055e+00,  3.14159265e+00,  2.75780157e+00, -3.13779424e+00]), array([-2.25187681e+00, -3.47253269e-01,  1.25171669e+00, -2.56220040e-03,
#        -3.28646130e-03, -8.59604310e-01, -2.77238802e+00, -1.14683979e+00,
#         3.14159265e+00, -2.81544717e+00, -2.92779516e-01,  1.33342200e-03,
#         1.28919643e+00,  1.76037872e+00,  2.17892610e-03,  9.68079159e-01,
#         1.85961518e+00, -3.00342553e+00, -5.07521473e-01, -3.58683370e-03,
#        -5.60101860e-02, -5.00312751e-01,  1.68665519e+00,  2.91512817e+00,
#         6.28960400e-04, -2.91820927e+00, -2.06437829e-01,  1.91973400e-04,
#         2.47267418e+00,  6.59958063e-01, -6.45975900e-04, -2.43621314e+00,
#        -1.61825190e+00,  2.84640606e+00,  1.12132896e+00,  1.19001229e-02,
#        -3.14159265e+00,  6.24279435e-02, -2.45999669e+00, -3.96698365e-01,
#        -4.30191350e-03,  8.49741786e-02, -5.07343365e-01,  3.13829385e+00,
#         4.22806597e-01,  1.88979398e+00, -2.75835987e+00,  1.46781635e+00,
#        -1.86104159e+00,  3.65940374e-01,  2.77763347e+00,  7.14096890e-03,
#        -3.07897442e+00,  2.72105221e+00, -1.64262923e+00, -1.31162070e+00,
#         4.80069700e-04,  2.04586478e-01,  2.70326836e+00,  3.13905777e+00,
#        -1.25166110e+00,  3.14159265e+00,  2.76053586e+00, -3.13733894e+00]), array([-2.25388157e+00, -3.48099393e-01,  1.25284998e+00, -9.40638170e-03,
#        -5.47571280e-03, -8.57214741e-01, -2.77921750e+00, -1.15355225e+00,
#         3.14159265e+00, -2.81562099e+00, -2.91872459e-01, -4.46678860e-03,
#         1.28882229e+00,  1.76036397e+00,  3.08777170e-03,  9.68465466e-01,
#         1.86128140e+00, -2.99702551e+00, -5.06059922e-01,  2.61025270e-03,
#        -3.09853783e-02, -4.98433650e-01,  1.68801451e+00,  2.93065546e+00,
#        -6.31881880e-03, -2.91937241e+00, -2.08944881e-01, -3.75459520e-03,
#         2.47135153e+00,  6.62953974e-01,  6.19222280e-03, -2.43495954e+00,
#        -1.61801891e+00,  2.85295090e+00,  1.12114383e+00,  1.15296561e-02,
#        -3.14159265e+00,  5.56752369e-02, -2.46676515e+00, -3.98093367e-01,
#         1.88805560e-03,  8.78714114e-02, -5.06670255e-01,  3.14159265e+00,
#         4.23643237e-01,  1.89377481e+00, -2.75946183e+00,  1.46820837e+00,
#        -1.86182104e+00,  3.70285666e-01,  2.77723986e+00,  2.83075690e-03,
#        -3.10303099e+00,  2.72479322e+00, -1.63825106e+00, -1.30923231e+00,
#        -2.13189680e-03,  2.05333567e-01,  2.70172165e+00,  3.14013609e+00,
#        -1.25274649e+00,  3.13922337e+00,  2.76005211e+00, -3.13756453e+00]), array([-2.25241741e+00, -3.47969626e-01,  1.25104803e+00, -6.84052060e-03,
#        -1.23813300e-04, -8.53998125e-01, -2.77768377e+00, -1.15213017e+00,
#         3.14159265e+00, -2.81456431e+00, -2.90481235e-01,  5.21060000e-06,
#         1.28826931e+00,  1.75974663e+00, -2.23940010e-03,  9.68290411e-01,
#         1.86143791e+00, -3.00011421e+00, -5.05128887e-01, -3.89652430e-03,
#        -4.12794698e-02, -5.00512469e-01,  1.68755007e+00,  2.92495959e+00,
#        -1.31016850e-03, -2.91925194e+00, -2.10413738e-01,  1.25487630e-03,
#         2.46943643e+00,  6.62193755e-01,  1.20018100e-03, -2.43568937e+00,
#        -1.61908017e+00,  2.85028545e+00,  1.11902069e+00,  9.03051700e-03,
#        -3.14159265e+00,  5.89344694e-02, -2.46516116e+00, -3.96464901e-01,
#         3.75518000e-04,  8.83726124e-02, -5.07764778e-01,  3.14073227e+00,
#         4.23968087e-01,  1.89142160e+00, -2.75780989e+00,  1.46795263e+00,
#        -1.86200106e+00,  3.68962842e-01,  2.77593838e+00,  1.72370340e-03,
#        -3.09971001e+00,  2.72116867e+00, -1.64143973e+00, -1.30765491e+00,
#        -4.82554000e-05,  2.04293819e-01,  2.70310247e+00,  3.14159265e+00,
#        -1.25309050e+00,  3.14009430e+00,  2.76166809e+00, -3.14093628e+00]), array([-2.25571453e+00, -3.50712363e-01,  1.25104338e+00, -1.32958781e-02,
#         1.42130420e-03, -8.50794025e-01, -2.78898828e+00, -1.16344303e+00,
#         3.14113274e+00, -2.81511872e+00, -2.93495764e-01, -9.08655000e-04,
#         1.28620303e+00,  1.75872704e+00,  2.91855600e-04,  9.68034809e-01,
#         1.86020723e+00, -3.00273699e+00, -5.04682710e-01, -8.17024520e-03,
#        -5.24939340e-03, -4.96780431e-01,  1.69029578e+00,  2.94986380e+00,
#         5.89930100e-04, -2.92092092e+00, -2.12926028e-01,  5.60489200e-04,
#         2.46507261e+00,  6.63882892e-01, -2.06885820e-03, -2.43464895e+00,
#        -1.61950519e+00,  2.84785211e+00,  1.11912483e+00,  7.99908850e-03,
#        -3.14159265e+00,  5.29141186e-02, -2.47520166e+00, -3.94875481e-01,
#         5.34581800e-04,  9.19060290e-02, -5.03494257e-01,  3.14159265e+00,
#         4.23236843e-01,  1.89763578e+00, -2.76493236e+00,  1.46779705e+00,
#        -1.86040793e+00,  3.68401733e-01,  2.77605007e+00, -8.58209400e-03,
#        -3.14159265e+00,  2.72879901e+00, -1.63541946e+00, -1.30189735e+00,
#         2.17608610e-03,  2.03281271e-01,  2.69992125e+00,  3.14159265e+00,
#        -1.25333168e+00,  3.14013402e+00,  2.75761464e+00, -3.14159265e+00]), array([-2.25344913e+00, -3.48082457e-01,  1.25197316e+00, -7.24733820e-03,
#         4.89415100e-04, -8.54400447e-01, -2.77881071e+00, -1.15641832e+00,
#         3.14159265e+00, -2.81532452e+00, -2.93101190e-01,  5.61160400e-04,
#         1.28836018e+00,  1.76018417e+00,  9.22256800e-04,  9.68255469e-01,
#         1.86047431e+00, -2.99959362e+00, -5.04780737e-01, -4.32170520e-03,
#        -2.86135699e-02, -5.00629379e-01,  1.68829298e+00,  2.93363440e+00,
#        -1.76289600e-04, -2.91842185e+00, -2.11237137e-01, -9.88982700e-04,
#         2.46866349e+00,  6.63351181e-01, -1.35694400e-04, -2.43511039e+00,
#        -1.61926772e+00,  2.84878495e+00,  1.11969865e+00,  8.26668620e-03,
#        -3.14159265e+00,  5.75109383e-02, -2.46965004e+00, -3.93752813e-01,
#         1.70393900e-04,  8.79857085e-02, -5.06098632e-01,  3.14159265e+00,
#         4.22956389e-01,  1.89363635e+00, -2.76042632e+00,  1.46805086e+00,
#        -1.86096529e+00,  3.68473111e-01,  2.77696778e+00, -1.16910180e-03,
#        -3.11432158e+00,  2.72545768e+00, -1.63897122e+00, -1.30464825e+00,
#         3.58169200e-04,  2.03354657e-01,  2.70322441e+00,  3.14120246e+00,
#        -1.25287756e+00,  3.14159265e+00,  2.76088157e+00, -3.14117454e+00]), array([-2.25495890e+00, -3.48872995e-01,  1.25297759e+00, -9.58183710e-03,
#         1.59863100e-04, -8.52904637e-01, -2.78476629e+00, -1.16238180e+00,
#         3.14061582e+00, -2.81659550e+00, -2.95106267e-01, -2.52354800e-04,
#         1.28798888e+00,  1.76271497e+00,  3.74930000e-06,  9.67349444e-01,
#         1.86013716e+00, -2.99960663e+00, -5.05382804e-01, -2.42874930e-03,
#        -4.74637750e-03, -5.00622620e-01,  1.68859067e+00,  2.94922796e+00,
#        -5.73031600e-04, -2.91834955e+00, -2.13187234e-01,  2.04384280e-03,
#         2.46546539e+00,  6.63745537e-01,  6.66873300e-04, -2.43503219e+00,
#        -1.61947616e+00,  2.84786703e+00,  1.12225839e+00,  6.65601230e-03,
#        -3.14115507e+00,  5.40578554e-02, -2.47585751e+00, -3.92495091e-01,
#         7.41190800e-04,  8.83762695e-02, -5.04912683e-01,  3.14159265e+00,
#         4.23287431e-01,  1.89472594e+00, -2.76075483e+00,  1.46724878e+00,
#        -1.86038515e+00,  3.68344318e-01,  2.77918460e+00, -4.51527070e-03,
#        -3.13623174e+00,  2.72920934e+00, -1.63523551e+00, -1.30114934e+00,
#         2.27200800e-04,  2.02768681e-01,  2.70361294e+00,  3.14159265e+00,
#        -1.25401162e+00,  3.14159265e+00,  2.76246264e+00, -3.14159265e+00]), array([-2.25505754e+00, -3.49544534e-01,  1.25398389e+00, -8.52739080e-03,
#        -3.91920800e-04, -8.52801293e-01, -2.78789515e+00, -1.16425664e+00,
#         3.13995570e+00, -2.81679140e+00, -2.93625181e-01, -9.33939300e-04,
#         1.28747258e+00,  1.76219994e+00, -5.47978200e-04,  9.67452833e-01,
#         1.86087120e+00, -3.00107944e+00, -5.05169245e-01, -1.90409260e-03,
#        -4.28340080e-03, -4.98886305e-01,  1.69039257e+00,  2.94614779e+00,
#        -8.50956000e-04, -2.91875671e+00, -2.13620979e-01,  2.84787110e-03,
#         2.46673455e+00,  6.64202825e-01, -1.55396800e-04, -2.43495988e+00,
#        -1.61914810e+00,  2.84934694e+00,  1.12119094e+00,  5.50967570e-03,
#        -3.14159265e+00,  5.18551599e-02, -2.47431074e+00, -3.93164432e-01,
#         1.52417850e-03,  8.90053689e-02, -5.05701150e-01,  3.14159265e+00,
#         4.22556201e-01,  1.89520219e+00, -2.76239141e+00,  1.46733915e+00,
#        -1.86063344e+00,  3.69346233e-01,  2.77840198e+00, -4.77866920e-03,
#        -3.13600237e+00,  2.72714602e+00, -1.63214524e+00, -1.30074298e+00,
#         4.73684300e-04,  2.03510500e-01,  2.70393678e+00,  3.14159265e+00,
#        -1.25311118e+00,  3.14066455e+00,  2.76050597e+00, -3.14159265e+00]), array([-2.25478352e+00, -3.49527765e-01,  1.25340736e+00, -7.65599720e-03,
#        -5.62943600e-04, -8.51804503e-01, -2.78761662e+00, -1.16290384e+00,
#         3.13982170e+00, -2.81700421e+00, -2.93995825e-01, -4.45770400e-04,
#         1.28692310e+00,  1.76208856e+00, -1.50937480e-03,  9.67463709e-01,
#         1.86145896e+00, -3.00152458e+00, -5.05537229e-01, -3.09026550e-03,
#        -5.84560250e-03, -4.99635138e-01,  1.68747262e+00,  2.94663182e+00,
#        -5.34018200e-04, -2.91911653e+00, -2.12239653e-01,  4.27360900e-04,
#         2.46760048e+00,  6.64159381e-01, -7.41686800e-04, -2.43507461e+00,
#        -1.61924129e+00,  2.85024622e+00,  1.12104418e+00,  4.67987290e-03,
#        -3.14159265e+00,  5.05629407e-02, -2.47398140e+00, -3.94789690e-01,
#         1.11569180e-03,  8.90151054e-02, -5.04842530e-01,  3.14159265e+00,
#         4.22498033e-01,  1.89486226e+00, -2.76184146e+00,  1.46731714e+00,
#        -1.86117596e+00,  3.70024046e-01,  2.77807079e+00, -4.76684620e-03,
#        -3.13494950e+00,  2.72623338e+00, -1.63520469e+00, -1.30163878e+00,
#         6.68680800e-04,  2.04062940e-01,  2.70269807e+00,  3.14001741e+00,
#        -1.25276043e+00,  3.14053610e+00,  2.76066071e+00, -3.14159265e+00]), array([-2.25454198e+00, -3.49097666e-01,  1.25290911e+00, -7.47224050e-03,
#         1.21365400e-04, -8.52874408e-01, -2.78517927e+00, -1.16241457e+00,
#         3.14051597e+00, -2.81637493e+00, -2.93188885e-01,  6.33294000e-05,
#         1.28696557e+00,  1.76159639e+00, -5.67426500e-04,  9.67571095e-01,
#         1.86080530e+00, -3.00030320e+00, -5.04999098e-01, -3.11241950e-03,
#        -9.52319250e-03, -4.99805565e-01,  1.68846888e+00,  2.94444169e+00,
#        -6.53186300e-04, -2.91931919e+00, -2.12441861e-01, -2.88355700e-04,
#         2.46685146e+00,  6.63340086e-01,  3.55364400e-04, -2.43512218e+00,
#        -1.61948046e+00,  2.84903591e+00,  1.12082228e+00,  4.83327520e-03,
#        -3.14159265e+00,  5.35996325e-02, -2.47300830e+00, -3.93294238e-01,
#         1.30170540e-03,  8.92440703e-02, -5.05432643e-01,  3.14159265e+00,
#         4.22928085e-01,  1.89472670e+00, -2.76120779e+00,  1.46739242e+00,
#        -1.86095278e+00,  3.68973795e-01,  2.77767748e+00, -4.18428400e-03,
#        -3.13181992e+00,  2.72806414e+00, -1.63514141e+00, -1.30244566e+00,
#         4.32540600e-04,  2.03976304e-01,  2.70275109e+00,  3.14114629e+00,
#        -1.25300991e+00,  3.14159265e+00,  2.76093281e+00, -3.14135064e+00]), array([-2.25473873e+00, -3.48850469e-01,  1.25292998e+00, -6.91390820e-03,
#         2.47361300e-04, -8.52201040e-01, -2.78639334e+00, -1.16432112e+00,
#         3.14001417e+00, -2.81653854e+00, -2.93071152e-01, -5.93249700e-04,
#         1.28675608e+00,  1.76161363e+00,  5.52940000e-05,  9.67486157e-01,
#         1.86070117e+00, -2.99987531e+00, -5.04901697e-01, -2.21837820e-03,
#        -3.76491230e-03, -5.00318881e-01,  1.68832189e+00,  2.94797497e+00,
#        -8.10413600e-04, -2.91969012e+00, -2.12628194e-01,  8.68316100e-04,
#         2.46772136e+00,  6.64577868e-01, -4.45467000e-05, -2.43502352e+00,
#        -1.61980896e+00,  2.84855610e+00,  1.12113658e+00,  2.87982520e-03,
#        -3.14159265e+00,  5.25608348e-02, -2.47383578e+00, -3.92560749e-01,
#         1.45477540e-03,  8.96956646e-02, -5.05207524e-01,  3.14159265e+00,
#         4.22889019e-01,  1.89575273e+00, -2.76096952e+00,  1.46730949e+00,
#        -1.86094906e+00,  3.68982069e-01,  2.77763363e+00, -4.92567490e-03,
#        -3.13772060e+00,  2.72960146e+00, -1.63434570e+00, -1.30212209e+00,
#         4.22850600e-04,  2.04321014e-01,  2.70235398e+00,  3.14159265e+00,
#        -1.25291665e+00,  3.14075364e+00,  2.76118696e+00, -3.14111339e+00]), array([-2.25466858e+00, -3.49129547e-01,  1.25309624e+00, -6.55211930e-03,
#         3.45131500e-04, -8.52319964e-01, -2.78622617e+00, -1.16373203e+00,
#         3.14046817e+00, -2.81661376e+00, -2.93607105e-01, -7.24492000e-05,
#         1.28707943e+00,  1.76185938e+00,  1.89648800e-04,  9.67499934e-01,
#         1.86086361e+00, -3.00031511e+00, -5.04985316e-01, -1.96336250e-03,
#        -4.92531800e-03, -5.00158643e-01,  1.68869943e+00,  2.94737190e+00,
#        -4.63594200e-04, -2.91915401e+00, -2.12797604e-01,  9.29113000e-05,
#         2.46732538e+00,  6.64104832e-01,  5.16346000e-05, -2.43500188e+00,
#        -1.61971259e+00,  2.84901011e+00,  1.12094285e+00,  2.93459630e-03,
#        -3.14159265e+00,  5.26875915e-02, -2.47411108e+00, -3.92752056e-01,
#         1.12524980e-03,  8.92945330e-02, -5.05129577e-01,  3.14159265e+00,
#         4.22654407e-01,  1.89536335e+00, -2.76119431e+00,  1.46736790e+00,
#        -1.86092516e+00,  3.69145831e-01,  2.77775632e+00, -4.61246630e-03,
#        -3.13687122e+00,  2.72864935e+00, -1.63431813e+00, -1.30175940e+00,
#         2.93164900e-04,  2.03911854e-01,  2.70288480e+00,  3.14159265e+00,
#        -1.25301501e+00,  3.14159265e+00,  2.76133927e+00, -3.14159265e+00]), array([-2.25476434e+00, -3.48925356e-01,  1.25316570e+00, -3.78170170e-03,
#        -3.96704100e-04, -8.51997483e-01, -2.78732394e+00, -1.16525283e+00,
#         3.14061651e+00, -2.81672721e+00, -2.93916020e-01,  9.61398000e-05,
#         1.28727331e+00,  1.76205491e+00, -1.93264300e-04,  9.67543213e-01,
#         1.86070587e+00, -2.99998152e+00, -5.04693699e-01, -4.34212700e-04,
#         2.94706700e-04, -5.00217648e-01,  1.68889889e+00,  2.95010983e+00,
#        -1.33384900e-04, -2.91903929e+00, -2.13163687e-01, -1.84566400e-04,
#         2.46718383e+00,  6.64355705e-01, -3.91931000e-05, -2.43480367e+00,
#        -1.61993749e+00,  2.84876494e+00,  1.12115713e+00, -8.58298100e-04,
#        -3.14159265e+00,  5.16204549e-02, -2.47516270e+00, -3.92421194e-01,
#         9.84993100e-04,  8.93617189e-02, -5.04993371e-01,  3.14159265e+00,
#         4.22525981e-01,  1.89562193e+00, -2.76145390e+00,  1.46743735e+00,
#        -1.86079892e+00,  3.68991237e-01,  2.77773108e+00, -4.79770590e-03,
#        -3.14159265e+00,  2.72952292e+00, -1.63347784e+00, -1.30082302e+00,
#         1.76029900e-04,  2.03762165e-01,  2.70318606e+00,  3.14159265e+00,
#        -1.25313439e+00,  3.14159265e+00,  2.76126443e+00, -3.14159265e+00]), array([-2.25473667e+00, -3.48990008e-01,  1.25310387e+00, -2.93670350e-03,
#        -3.69580000e-06, -8.51971986e-01, -2.78727571e+00, -1.16522255e+00,
#         3.14104058e+00, -2.81675155e+00, -2.93891947e-01, -2.97648000e-05,
#         1.28722896e+00,  1.76207599e+00,  3.79810000e-06,  9.67508380e-01,
#         1.86075111e+00, -3.00020313e+00, -5.04798181e-01,  8.38311000e-05,
#        -1.05253900e-04, -5.00233271e-01,  1.68881561e+00,  2.94991931e+00,
#        -9.48708000e-05, -2.91909282e+00, -2.13046107e-01, -4.84700000e-07,
#         2.46722828e+00,  6.64184158e-01, -3.24220000e-06, -2.43485887e+00,
#        -1.61989174e+00,  2.84895907e+00,  1.12109142e+00, -1.53096540e-03,
#        -3.14159265e+00,  5.17530414e-02, -2.47498612e+00, -3.92449400e-01,
#         5.63241600e-04,  8.93674127e-02, -5.04976956e-01,  3.14153968e+00,
#         4.22509866e-01,  1.89552354e+00, -2.76133668e+00,  1.46739998e+00,
#        -1.86082018e+00,  3.69038735e-01,  2.77774148e+00, -4.34144910e-03,
#        -3.14148118e+00,  2.72948882e+00, -1.63349608e+00, -1.30100651e+00,
#         7.44895000e-05,  2.03797530e-01,  2.70321117e+00,  3.14153206e+00,
#        -1.25307901e+00,  3.14159265e+00,  2.76132450e+00, -3.14156098e+00]), array([-2.25473667e+00, -3.48990008e-01,  1.25310387e+00, -2.93670350e-03,
#        -3.69580000e-06, -8.51971986e-01, -2.78727571e+00, -1.16522255e+00,
#         3.14104058e+00, -2.81675155e+00, -2.93891947e-01, -2.97648000e-05,
#         1.28722896e+00,  1.76207599e+00,  3.79810000e-06,  9.67508380e-01,
#         1.86075111e+00, -3.00020313e+00, -5.04798181e-01,  8.38311000e-05,
#        -1.05253900e-04, -5.00233271e-01,  1.68881561e+00,  2.94991931e+00,
#        -9.48708000e-05, -2.91909282e+00, -2.13046107e-01, -4.84700000e-07,
#         2.46722828e+00,  6.64184158e-01, -3.24220000e-06, -2.43485887e+00,
#        -1.61989174e+00,  2.84895907e+00,  1.12109142e+00, -1.53096540e-03,
#        -3.14159265e+00,  5.17530414e-02, -2.47498612e+00, -3.92449400e-01,
#         5.63241600e-04,  8.93674127e-02, -5.04976956e-01,  3.14153968e+00,
#         4.22509866e-01,  1.89552354e+00, -2.76133668e+00,  1.46739998e+00,
#        -1.86082018e+00,  3.69038735e-01,  2.77774148e+00, -4.34144910e-03,
#        -3.14148118e+00,  2.72948882e+00, -1.63349608e+00, -1.30100651e+00,
#         7.44895000e-05,  2.03797530e-01,  2.70321117e+00,  3.14153206e+00,
#        -1.25307901e+00,  3.14159265e+00,  2.76132450e+00, -3.14156098e+00])]

# %%
from qiskit.aqua.components.variational_forms.ry import RY
from qiskit.aqua.components.variational_forms.ryrz import RYRZ

import numpy as np

num_qubits = N_col*N_row
depth = var_form_cfg['depth']
entanglement = var_form_cfg['entanglement']
type_of_variation = var_form_cfg['name']

if type_of_variation == 'RY':
    circ = RY(num_qubits, depth=depth, entanglement=entanglement)
elif type_of_variation == 'RYRZ':
    circ = RYRZ(num_qubits, depth=depth, entanglement=entanglement)
    
#print(circ.construct_circuit(parameter[0]))

# %%
from qiskit import BasicAer, execute

def outputstate(circ):
    backend = BasicAer.get_backend('statevector_simulator')
    # Create a Quantum Program for execution 
    job = execute(circ, backend)
    result = job.result()
    outputstate = result.get_statevector(circ, decimals=3)
    return outputstate

output = []
for par in parameter:
    circuit = circ.construct_circuit(par)
    output.append(outputstate(circuit))

# %%
#Lets visualize the density matrix.
from qiskit.tools.visualization import plot_state_city
import os
import shutil

path1 = os.getcwd()
print(path1)
path2 = path1+'\density'

shutil.rmtree(path2, ignore_errors=True)

#os.mkdir(path2)
os.chdir(path2)

#for i in range(len(output)):
#    fig = plot_state_city(output[i])
#    fig.savefig('density' + str(i)+ '.png')

os.chdir(path1)
# Out:
# C:\Users\javig\Dropbox\TFG (Javier Galván)

# %% [raw]
# import imageio
# import os, sys
# import glob
#
# dataDir = path2
#
# os.chdir(dataDir)
# fileList = glob.glob(dataDir + '\*.png')
# fileList.sort(key=lambda s: int(s[58:-4]))
#
# images = []
#
# for filename in fileList:
#     images.append(imageio.imread(filename))
#
# kargs = { 'fps': 1 }
#
# imageio.mimsave('density_movie.gif', images, **kargs)

# %% [raw]
# from IPython.display import Image
# Image(filename="density_movie.gif")

# %%
from numpy.linalg import svd as svd

def ent_entropy(psi, m ,n):
    a = np.reshape(np.array(psi), (2**m, 2**(n-m)))
    singular_val = svd(a)[1]
    logarithm = np.ma.log2(singular_val)
    logarithm = np.ma.filled(logarithm, 0)
    s = singular_val * logarithm
    return -np.sum(s)

def max_entropy(psi, num_qubits):
    lista = [ent_entropy(psi, m, num_qubits) for m in range(1, num_qubits)]
    return max(lista)

#max_entropy(output[0], num_qubits)

# %%
from matplotlib import animation, rc
from IPython.display import HTML

#Get entropy
S = []

for out in output:
    S.append(max_entropy(out, num_qubits))
    
print(S)
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, len(S)))
ax.set_ylim((0, max(S)))
ax.set_xlabel('# of iterations')
ax.set_ylabel('Entropy (bits)')

line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    x = range(0, i+1)
    y = S[0:i+1]
    line.set_data(x, y)
    return (line,)

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(S), interval=1000, blit=True)
os.chdir(path2)
anim.save('entropy.gif', writer='imagemagick', fps=1)
print('hola')
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3f3677f062be> in <module>
#       6
#       7 for out in output:
# ----> 8     S.append(max_entropy(out, num_qubits))
#       9
#      10 print(S)
#
# <ipython-input-6-67dd6343d69c> in max_entropy(psi, num_qubits)
#      10
#      11 def max_entropy(psi, num_qubits):
# ---> 12     lista = [ent_entropy(psi, m, num_qubits) for m in range(1, num_qubits)]
#      13     return max(lista)
#      14
#
# <ipython-input-6-67dd6343d69c> in <listcomp>(.0)
#      10
#      11 def max_entropy(psi, num_qubits):
# ---> 12     lista = [ent_entropy(psi, m, num_qubits) for m in range(1, num_qubits)]
#      13     return max(lista)
#      14
#
# <ipython-input-6-67dd6343d69c> in ent_entropy(psi, m, n)
#       3 def ent_entropy(psi, m ,n):
#       4     a = np.reshape(np.array(psi), (2**m, 2**(n-m)))
# ----> 5     singular_val = svd(a)[1]
#       6     logarithm = np.ma.log2(singular_val)
#       7     logarithm = np.ma.filled(logarithm, 0)
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1610
#    1611         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1612         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1613         u = u.astype(result_t, copy=False)
#    1614         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %% [raw]
# import moviepy.editor as mpy
# # We use the GIFs generated earlier to avoid recomputing the animations.
# clip_mayavi = mpy.VideoFileClip("density_movie.gif")
# clip_mpl = mpy.VideoFileClip("entropy.gif").resize(height=clip_mayavi.h)
# animation = mpy.clips_array([[clip_mpl, clip_mayavi]])
# animation.write_gif("sinc_plot.gif", fps=20)
#
# Image(filename="sinc_plot.gif")

# %% [markdown]
# ### Appendix 1: Singular Value Decomposition
#
# Generalization of the eigendecomposition of a positive semidefinite normal matrix to a $m\times n$ matrix via an extension of the polar decomposition:
#
# \begin{equation}
# M = U \Sigma V^{\dagger}
# \end{equation}
#
# where $\Sigma$ is a rectangular matrix and $U$ and $V$ are unitary matrices satisfying:
#
# \begin{equation}
# U U^{\dagger} = I\\
# V V^{\dagger} = I
# \end{equation}

# %% [markdown]
# ## Bibliography
#
# **[1]** Zulko. (2014, November 29). Data Animations With Python and MoviePy. Retrieved March 6, 2019, from http://zulko.github.io/blog/2014/11/29/data-animations-with-python-and-moviepy/
#
# **[2]** Nielsen, M. A., & Chuang, I. (2002). Quantum computation and quantum information.
#
# **[3]** Louisiana State University, M. M. (2015, September 16). Introduction to Quantum Information Theory—PHYS 7895. Retrieved from http://www.markwilde.com/teaching/2015-fall-qit/lectures/lecture-07.pdf
#
#
# https://cs.stackexchange.com/questions/56261/computing-von-neumann-entropy-efficiently
#
# https://physics.stackexchange.com/questions/251522/how-do-you-find-a-schmidt-basis-and-how-can-the-schmidt-decomposition-be-used-f
#
# http://www.thphys.nuim.ie/staff/jvala/Lecture_9.pdf
#
# http://web.mit.edu/2.111/www/2010/ps3_2010Sol2.pdf
#
# https://en.wikipedia.org/wiki/Entropy_of_entanglement
#
# https://es.wikipedia.org/wiki/Entrop%C3%ADa_de_von_Neumann
#
# https://en.wikipedia.org/wiki/Singular_value_decomposition#Analytic_result_of_2_%C3%97_2_SVD
#
# https://en.wikipedia.org/wiki/Schmidt_decomposition
#
# https://www.quantiki.org/wiki/bipartite-states-and-schmidt-decomposition
